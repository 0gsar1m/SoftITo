# %%
isim = 'Ahmet' # string/str
yas = 28       #integer/int
boy = 1.74     # Float
ogrenci_mi = True #Boolean/bool
print(isim,yas,boy,ogrenci_mi)
# Out:
# Ahmet 28 1.74 True

# %%
print(type(isim))
print(type(yas))
print(type(boy))
print(type(ogrenci_mi))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ## Temel matematik işlemleri

# %%
a=10
b=11

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# 21
# -1
# 110
# 0.9090909090909091
# 0
# 10
# 100000000000
# False
# True
# False
# True
# False
# True

# %%
isim = input("İsminiz nedir?")
print("Merhaba", isim)
# Out:
# Merhaba asd

# %%
yas = input("Yaşınız kaç?")
print(yas, "yaşındasın")
print(" gelecek yıl", yas+1, "yaşındasın")

# %%
yas = input("Yaşınız kaç?")
print(yas, "yaşındasın")
print(type(yas))
#print(" gelecek yıl", yas+1, "yaşındasın")
# Out:
# 12 yaşındasın
# <class 'str'>

# %%
yas= int(input("Yaşınız kaç?"))
print(yas, "yaşındasın")
yas = int(yas)
print(type(yas))
print(" gelecek yıl", yas+1, "yaşındasın")
# Out:
# 21 yaşındasın
# <class 'int'>
#  gelecek yıl 22 yaşındasın

# %%
yas = input("Yaşınız kaç?")
print(yas, "yaşındasın")
yas = int(yas)
print(type(yas))
print(" gelecek yıl", yas+1, "yaşındasın")
# Out:
# 122 yaşındasın
# <class 'int'>
#  gelecek yıl 123 yaşındasın

# %%
yas = 20
ehliyet_var = True

print(yas >= 18 and ehliyet_var)
print(yas >= 18 or ehliyet_var)
print(not ehliyet_var)
# Out:
# True
# True
# False

# %%
yas  = 15

if yas >= 18:
  print('Reşitsin')
else:
  print('Reşit değil')
# Out:
# Reşit değil

# %%
ad = 'ömer'
soyadı = 'hattab'

tam_isim = ad + " " + soyadı
print(tam_isim)

print(len(ad))
print(ad.upper())
print(soyadı.lower())
# Out:
# ömer hattab
# 4
# ÖMER
# hattab

# %%
yas = 25
print(f"Yaşım: {yas}") # print('Yaşım:'+ str(yas))
# Out:
# Yaşım: 25

# %%
sayi1=  int(input('Bir sayı giriniz:'))
sayi2 = int(input('Bir sayı giriniz:'))

if sayi1 > sayi2:
  print(f'{sayi1} sayısı {sayi2} sayısından büyüktür')
else:
  print(f'{sayi2} sayısı' )
# Out:
# 2 sayısı 1 sayısından büyüktür

# %%
sayi1= int(input('Bir sayı giriniz:'))
sayi2 = int(input('Bir sayı giriniz:'))

toplam = sayi1+sayi2
print(f'Toplam: {toplam}')
# Out:
# Toplam: 5

# %% [markdown]
# # SORULAR

# %%
# 1
print("python öğreniyom: Emir Kaan Oğşarim")
print(2)
print("yazı")
# Out:
# python öğreniyom: Emir Kaan Oğşarim
# 2
# yazı

# %%
#2
'''Emir
   23
   İstanbul '''

print(123) # girilen sayıyı ekrana yazdırır
# Out:
# 123

# %%
#3

sehir = 'İstanbul'
print(sehir)

puan = 50
print(puan)
puan += 25
print(puan)
# Out:
# İstanbul
# 50
# 75

# %%
#4

isim = 'Emir' # string/str
yas = 23       #integer/int
boy = 1.68     # Float
sisko_mu = True
yakisikli_mi = True

print(type(isim))
print(type(yas))
print(type(boy))
print(type(sisko_mu))
print(type(yakisikli_mi))

print(10 == '10')
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>
# False

# %%
#5
toplama = 15 + 4
cikarma = 15 - 4
carpma = 15 * 4
bolme = 15 / 4

mod_islemi = 17 % 5

us_alma = 2 ** 8


print("Toplama:", toplama)
print("Çıkarma:", cikarma)
print("Çarpma:", carpma)
print("Bölme:", bolme)
print("Mod:", mod_islemi)
print("Üs alma:", us_alma)
# Out:
# Toplama: 19
# Çıkarma: 11
# Çarpma: 60
# Bölme: 3.75
# Mod: 2
# Üs alma: 256

# %%
#6
isim = input("Adın ney?")
print(f"merhaba {isim}!")

yas = int(input("yaş kaç?"))
print("10 yıl sonra", yas+10, "yaşındasın")
# Out:
# merhaba asd!
# 10 yıl sonra 133 yaşındasın

# %%
#7
a = 8
b = 12
print(a > b)
print(a < b)
print(a == b)

s1 = int(input("Sayı: "))
print(s1 == 100)
# Out:
# False
# True
# False
# False

# %%
# 8
yas = 22
ogrenci = False
print(yas > 18 and ogrenci)
print(yas > 18 or ogrenci)
print(not ogrenci)

kayitli_mi = True
print(yas > 18 and kayitli_mi)
# Out:
# False
# True
# True
# True

# %%
# 9
s2 = int(input("Sayı: "))
if s2 > 0:
    print("Pozitif")
else:
    print("Negatif")

notu = int(input("Not: "))
if notu >= 50:
    print("Geçti")
else:
    print("Kaldı")
# Out:
# Pozitif
# Geçti

# %%
# 10
ad = "Ali"
soyad = "Can"
tam_ad = ad + " " + soyad
print(tam_ad)

harf_sayisi = "Python"
print(len(harf_sayisi))

yazi = "Merhaba"
print(yazi.upper())
print(yazi.lower())
# Out:
# Ali Can
# 6
# MERHABA
# merhaba

# %%
# 11
x = int(input("Çarpılcak ilk Sayı: "))
y = int(input("Çarpılcak ikinci Sayı: "))
print(x * y)

z = int(input("Sayı: "))
print(z * z)
# Out:
# 45
# 9

# %% [markdown]
# ## 2. Oturum

# %%
oda_sayisi = 3
kisi_basi=25000

toplam_maliyet = oda_sayisi*kisi_basi
print(f'Toplam maliyet: {toplam_maliyet}')
# Out:
# Toplam maliyet: 75000

# %%
toplam_maliyet += 5000
print(f'Toplam maliyet: {toplam_maliyet}')
# Out:
# Toplam maliyet: 80000

# %%
toplam_maliyet -= 5000
print(f'Toplam maliyet: {toplam_maliyet}')
# Out:
# Toplam maliyet: 75000

# %%
yas = 20
ehliyet_var = True

if yas >= 18 :
  if ehliyet_var:
    print('Reşitsiniz ve ehliyet var')
  else:
    print('Reşitsiniz ama ehliyet yok')
else:
  print('Reşit değilsiniz')
# Out:
# Reşitsiniz ve ehliyet var

# %%
Hasanın_notu = 65

if Hasanın_notu >= 85:
  print('A notu aldınız')
elif Hasanın_notu >= 70:
  print('B notu aldınız')
elif Hasanın_notu >= 55:
  print('C notu aldınız')
elif Hasanın_notu >= 45:
  print('D notu aldınız')
else:
  print('Kaldınız')
# Out:
# C notu aldınız

# %%
for i in range (1,9):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
sayilar = [12,45,7,23,65,87]
toplam = 0
for sayi in sayilar:
  toplam += sayi
print(toplam)
# Out:
# 239

# %%
sayac =1
while sayac <=5:
  print(f"{sayac}.adım")
  sayac +=1

print('döngü bitti')
# Out:
# 1.adım
# 2.adım
# 3.adım
# 4.adım
# 5.adım
# döngü bitti

# %%
sayilar = [12,45,7,23,65,87,23,34]

for sayi in sayilar:
  if sayi %2 ==0:
    print(f"{sayi} çift sayıdır")
  else:
    print(f"{sayi} tek sayıdır")
# Out:
# 12 çift sayıdır
# 45 tek sayıdır
# 7 tek sayıdır
# 23 tek sayıdır
# 65 tek sayıdır
# 87 tek sayıdır
# 23 tek sayıdır
# 34 çift sayıdır

# %%
def kare_al(sayi):
  sonuc= sayi**2
  return sonuc

kare_al(5)
# Out:
# 25

# %%
def selamla(isim):
  print(f"Merhaba {isim}")

selamla("Hasan")
# Out:
# Merhaba Hasan

# %%
def cift_mi(sayi):
  if sayi%2==0:
    return True
  else:
    return False
print(cift_mi(10))
print(cift_mi(11))
# Out:
# True
# False

# %%
def buyuk_kucuk(a,b):
  if a>b:
    return f"{a} daha büyük"
  elif a<b:
    return f"{b} daha büyük"
  else:
    return f"{a} ve {b} eşit"

print(buyuk_kucuk(10,20))
# Out:
# 20 daha büyük

# %%
meyveler = []

meyveler.append ("elma")
meyveler.append ("ejderha meyvesi")
meyveler.append ("cilek")

print(meyveler)


for i , meyve in enumerate(meyveler):
  print(f"{i+1}.{meyve}")
# Out:
# ['elma', 'ejderha meyvesi', 'cilek']
# 1.elma
# 2.ejderha meyvesi
# 3.cilek

# %%
isim = input("İsminiz nedir: ")
yas = int(input("Yaşınız kaç:  "))
sehir = input("Sehriniz: ")

print(f"\n ------- Bilgileriniz-------")
print(f"İsim: {isim}")
print(f"Yaş: {yas}")
print(f"Şehir: {sehir}")
# Out:
#  ------- Bilgileriniz-------
# İsim: asd
# Yaş: 1
# Şehir: asdf

# %%
ders_sayisi= int(input("Kaç ders aldınız: "))
notlar= []

for i in range(ders_sayisi):
  nots=float(input(f"{i+1}.ders notunuzu giriniz: "))
  notlar.append(nots)


ortalama  = sum(notlar)/len(notlar)
print(f"Ortalamanız: {ortalama}")


if ortalama >= 60:
  print('Başarılısınız')
else:
  print('Başarısız')
# Out:
# Ortalamanız: 28.0
# Başarısız

# %%
sepet = []
toplam_fiyat = 0


for i in range(4):
  urun = input("Ürün adı: ")
  fiyat = float(input("Ürün fiyatı: "))
  sepet.append((urun))
  toplam_fiyat += fiyat

print("\n--- Sepetiniz")
for urun in sepet:
  print("-",urun)
print(f"Toplam fiyat: {toplam_fiyat}")
# Out:
# --- Sepetiniz
# - süt
# - asd
# - asdf
# - asdfg
# Toplam fiyat: 1393.0

# %%
# 1.1

urun_fiyat = 25
urun_adet = 5

toplam_tutar = urun_adet * urun_fiyat
print(str(toplam_tutar) + " TL")

# 1.2
maas = 8000
maas+= 1500
print("Maaş: " + str(maas))
# Out:
# 125 TL
# Maaş: 9500

# %%
# 2.1

yas = int(input("Yaşınız: "))
ogrenci_mi = input("Öğrenci misiniz? (e/h): ").strip().lower()

if yas > 65:
    print("ücretsiz")
else:
    if ogrenci_mi == "e":
        print("indirimli")
    else:
        print("tam ücret")

# 2.2
i = int(input("Sayı gir: "))
if i > 0:
    if(i % 2 == 0):
        print("Sayı pozitif ve çift")
    else:
        print("Sayı pozitif ve tek")
else:
    if(i % 2 == 0):
        print("Sayı negatif ve çift")
    else:
        print("Sayı negatif ve tek")
# Out:
# ücretsiz
# Sayı negatif ve çift

# %%
# 3.1

sicaklik = float(input("Hava kaç derece: "))

if sicaklik > 30:
    print("Yanıor")
elif 15 <= sicaklik <= 30:
    print("idare eder")
else:
    print("büzüştüm")
    
# 3.2

ay = int(input("Kaçıncı aydasın la (1-12): "))

if ay in (12, 1, 2):
    print("Kış")
elif ay in (3, 4, 5):
    print("İlkbahar")
elif ay in (6, 7, 8):
    print("Yaz")
elif ay in (9, 10, 11):
    print("Sonbahar")
else:
    print("yarmacan, doğru gir")
# Out:
# Sıcak
# Yaz

# %%
# 4.1
nums = [6, 16, 9, 23, 4, 20]
max = nums[0]

for i in nums:
    if i > max:
        max = i

print(f"En büyük sayı: {max}")

# 4.2
count_bigger_than_10 = 0;

for i in nums:
    if i > 10:
        count_bigger_than_10+=1;

print(f"10'dan büyük sayıların countu: {count_bigger_than_10}")
# Out:
# En büyük sayı: 23
# 10'dan büyük sayıların countu: 3

# %%
# 5.1

counter = 5;

while counter >=1:
    print(counter)
    counter-=1;

# 5.2
password = "cikolata123";
ent_pass = "";

while ent_pass != password:
    ent_pass = input("Şifreyi girin: ")
    if ent_pass != password:
        print("Bi daha dene")
    
print("Giriş başarılı")
# Out:
# 5
# 4
# 3
# 2
# 1
# Bi daha dene
# Giriş başarılı

# %%
# 6.1

print("3'e bölünenler:")
for sayi in range(1, 18):
    if sayi % 3 == 0:
        print(str(sayi) + " ")

# 6.2

numss = [12, -4, 0, 7, -19, 23, -8, 5]
pozitifsss = []
negatifsss = []

for n in numss:
    if n > 0:
        pozitifsss.append(n)
    elif n < 0:
        negatifsss.append(n)

print(f"Pos: {pozitifsss}")
print(f"Neg: {negatifsss}")
# Out:
# 3'e bölünenler:
# 3
# 6
# 9
# 12
# 15
# Pos: [12, 7, 23, 5]
# Neg: [-4, -19, -8]

# %%
# 7.1

def kup_al(sayi):
    return sayi ** 3

print("4 küpü:", kup_al(4))

# 7.2
def sum(a, b):
    return a + b

print("7 + 14 =", sum(7, 14))
# Out:
# 4 küpü: 64
# 7 + 14 = 21

# %%
# 8.1

def pos_or_neg(num):
    if num > 0:
        return "Pozitifsss"
    elif num < 0:
        return "Negatifsss"
    else:
        return "Sıfırss"
    
print("-2:", pos_or_neg(-2))
print("12:", pos_or_neg(12))
print("0:", pos_or_neg(0))

# 8.2

def big_of_3(a, b, c):
    if(a > b) and (a>c):
        return a;
    elif(b > a) and (b>c):
        return b;
    else:
        return c;
    
print(big_of_3(1,2,3))
# Out:
# -2: Negatifsss
# 12: Pozitifsss
# 0: Sıfırss
# 3

# %%
# 9.1

sehirler = []

for i in range(4):
    yeni_sehir = input(f"{i}. Sehri girin: ")
    i+=1
    sehirler.append(yeni_sehir)

print("Listedeki sehirler: ")
for i in sehirler:
    print(i)

# 9.2

urunler = []

for i in range(4):
    yeni_urun = input(f"{i}. Urunu girin: ")
    i += 1
    urunler.append(yeni_urun)

print("Listedeki urunler: ")
for i in urunler:
    print(i)

silinecek = input("Silmek istediğiniz ürünü yazın: ")
if silinecek in urunler:
    urunler.remove(silinecek)
    print("Güncel liste: ")
    for i in urunler:
        print(i)
else:
    print("Ürün listede bulunamadı.")
# Out:
# Listedeki sehirler:
# a
# b
# c
# d
# Listedeki urunler:
# a
# q
# w
# e
# Güncel liste:
# a
# q
# e

# %%
# 10.1

ad = input("Adınız: ")
soyad = input("Soyadınız: ")
yiliniz= int(input("Bulunduğunuz yıl: "))
dogum_yili = int(input("Doğum yılınız: "))

yas = yiliniz - dogum_yili
print(f"{ad} {soyad}, {yiliniz} yılı itibarıyla yaşınız: {yas}")

# 10.2

boy_cm = float(input("Boyunuzu girin (cm olarak): "))
kilo = float(input("Kilonuzu girin (kg olarak): "))

boy_m = boy_cm / 100
bmi = kilo / (boy_m ** 2)

if bmi < 30:
    print(f"BMI'niz: {bmi:.3f}")
else:
    print("BMI'niz: DOMBİLİ")
# Out:
# wqasd asd, 1234 yılı itibarıyla yaşınız: 1222
# BMI'niz: DOMBİLİ

# %%
# Kalanına üşenip gemini'ye attım
# 11.1


notlar = []

for i in range(4):
    not_degeri = float(input(f"{i + 1}. ders notunu girin: "))
    notlar.append(not_degeri)

ortalama = sum(notlar) / len(notlar)

# Harf notu eşleme
if ortalama >= 90:
    harf = "AA"
elif ortalama >= 85:
    harf = "BA"
elif ortalama >= 80:
    harf = "BB"
elif ortalama >= 70:
    harf = "CB"
elif ortalama >= 60:
    harf = "CC"
elif ortalama >= 50:
    harf = "DC"
else:
    harf = "FF"

print(f"\nOrtalama: {ortalama:.2f}")
print(f"Harf Notu: {harf}")
print(f"En Yüksek Not: {max(notlar)}")
print(f"En Düşük Not: {min(notlar)}")
# Out:
# Ortalama: 2.50
# Harf Notu: FF
# En Yüksek Not: 4.0
# En Düşük Not: 1.0

# %%
# 12.1

sepet = [
    {"urun": "Kulaklık", "fiyat": 350},
    {"urun": "Kablo", "fiyat": 80},
    {"urun": "Mousepad", "fiyat": 150},
    {"urun": "USB Bellek", "fiyat": 90}
]

print("100 TL Üzerindeki Ürünler:")
pahali_urunler = []
for urun in sepet:
    if urun["fiyat"] > 100:
        pahali_urunler.append(urun)
        print(f"- {urun['urun']}: {urun['fiyat']} TL")

# 12.2
toplam_tutar = sum(urun["fiyat"] for urun in sepet)
print(f"\nAra Toplam: {toplam_tutar} TL")

if toplam_tutar > 500:
    odenecek_tutar = toplam_tutar * 0.90
    print("%10 indirim kazandınız!")
    print(f"Ödenecek Nihai Tutar: {odenecek_tutar:.2f} TL")
else:
    print(f"Ödenecek Tutar: {toplam_tutar:.2f} TL")
# Out:
# 100 TL Üzerindeki Ürünler:
# - Kulaklık: 350 TL
# - Mousepad: 150 TL
#
# Ara Toplam: 670 TL
# %10 indirim kazandınız!
# Ödenecek Nihai Tutar: 603.00 TL
