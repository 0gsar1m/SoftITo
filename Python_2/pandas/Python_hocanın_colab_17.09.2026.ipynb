# %%
#pandas kurulumu
# !pip install pandas
# Out:
# ^C

# %%
import pandas as pd
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.5.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    --------------------------- ------------ 6.8/10.0 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 31.6 MB/s  0:00:00
# Downloading numpy-2.5.3-cp314-cp314-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 12.7/12.7 MB 64.4 MB/s  0:00:00
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tzdata-2026.4-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, six, numpy, python-dateutil, pandas
#
#    ---------------------------------------- 0/5 [tzdata]
#    ---------------------------------------- 0/5 [tzdata]
#    ---------------------------------------- 0/5 [tzdata]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ------------------------ --------------- 3/5 [python-dateutil]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
#    ---------------------------------------- 5/5 [pandas]
#
# Successfully installed numpy-2.5.3 pandas-3.0.5 python-dateutil-2.9.0.post0 six-1.17.0 tzdata-2026.4
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\emir\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: C:\Users\emir\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
sayilar = pd.Series([10,20,30,40,50])
print(sayilar)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
notlar = pd.Series([85,90,78], index = ['Ayşe','Fatma','Hayriye'])

# %%
print(notlar)
# Out:
# Ayşe       85
# Fatma      90
# Hayriye    78
# dtype: int64

# %%
veri ={
    "isim" : ["Ayşe","Fatma","Hayriye"],
    "yas" : [23,25,30],
    "sehir" : ["Ankara","İstanbul","İzmir"]
}

df =pd.DataFrame(veri)
print(df)
# Out:
#       isim  yas     sehir
# 0     Ayşe   23    Ankara
# 1    Fatma   25  İstanbul
# 2  Hayriye   30     İzmir

# %%
df = pd.read_csv("/content/grocery_chain_data.csv")

# %%
df_new = pd.read_excel("/content/Superlig_Proje.xlsx")

# %%
df.head(2)
# Out:
#    customer_id         store_name transaction_date    aisle product_name  \
# 0         2824  GreenGrocer Plaza       2023-08-26  Produce        Pasta
# 1         5506   ValuePlus Market       2024-02-13    Dairy       Cheese
#
#    quantity  unit_price  total_amount  discount_amount  final_amount  \
# 0       2.0        7.46         14.92             0.00         14.92
# 1       1.0        1.85          1.85             3.41         -1.56
#
#    loyalty_points
# 0             377
# 1             111

# %%
df_new.head(2)
# Out:
#      Takim_Adi  Topa_Sahip_Olma Isabetli_Pas_Sayisi  Pas_Isabeti_Yuzde  \
# 0   Alanyaspor             48.5                 337               83.2
# 1  Antalyaspor             43.6                 279               79.6
#
#   Isabetli_Uzun_Top  Isabetli_Orta  Sut_Sayisi  Isabetli_Sut  \
# 0              17.1            4.8         206            67
# 1              18.8            3.3         142            59
#
#    xG_Gol_Beklentisi  Buyuk_Sans_Yaratma  ...  Basarili_Dripling  \
# 0               19.0                 2.2  ...                6.5
# 1               13.0                 1.2  ...                6.1
#
#    Rakip_Ceza_Sahasi_Dokunus  Top_Calma  Pas_Arasi  Uzaklastirma  \
# 0                  13.411765       12.2        7.8          21.4
# 1                  21.235294       15.8        7.0          29.4
#
#    Hucum_Bolgesi_Top_Calma  Zeminde_Kazanilan_Mucadele  \
# 0                      2.9                        33.8
# 1                      2.4                        35.5
#
#   Hava_Kazanilan_Mucadele Atilan_Gol  Yenilen_Gol
# 0                    11.6         16           15
# 1                    12.8         16           31
#
# [2 rows x 21 columns]

# %%
df_new.tail(2)
# Out:
#       Takim_Adi  Topa_Sahip_Olma Isabetli_Pas_Sayisi  Pas_Isabeti_Yuzde  \
# 16   Samsunspor             51.2                 331               81.6
# 17  Trabzonspor             54.2                 360               85.1
#
#    Isabetli_Uzun_Top  Isabetli_Orta  Sut_Sayisi  Isabetli_Sut  \
# 16              19.9            3.5         217            67
# 17              19.0            5.3         276           103
#
#     xG_Gol_Beklentisi  Buyuk_Sans_Yaratma  ...  Basarili_Dripling  \
# 16               24.4                 2.6  ...                6.9
# 17               27.1                 2.7  ...                9.8
#
#     Rakip_Ceza_Sahasi_Dokunus  Top_Calma  Pas_Arasi  Uzaklastirma  \
# 16                  23.058824       16.0        6.4          25.2
# 17                  24.470588       14.6        6.7          21.9
#
#     Hucum_Bolgesi_Top_Calma  Zeminde_Kazanilan_Mucadele  \
# 16                      3.5                       32.9
# 17                      4.1                        37.4
#
#    Hava_Kazanilan_Mucadele Atilan_Gol  Yenilen_Gol
# 16                    14.0         19           20
# 17                   13.4          33           20
#
# [2 rows x 21 columns]

# %%
df_new.shape
# Out:
# (18, 21)

# %%
df_new.columns
# Out:
# Index(['Takim_Adi', 'Topa_Sahip_Olma', 'Isabetli_Pas_Sayisi',
#        'Pas_Isabeti_Yuzde', 'Isabetli_Uzun_Top', 'Isabetli_Orta', 'Sut_Sayisi',
#        'Isabetli_Sut', 'xG_Gol_Beklentisi', 'Buyuk_Sans_Yaratma',
#        'Korner_Sayisi', 'Basarili_Dripling', 'Rakip_Ceza_Sahasi_Dokunus',
#        'Top_Calma', 'Pas_Arasi', 'Uzaklastirma', 'Hucum_Bolgesi_Top_Calma',
#        'Zeminde_Kazanilan_Mucadele', 'Hava_Kazanilan_Mucadele', 'Atilan_Gol',
#        'Yenilen_Gol'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1980 non-null   int64
#  1   store_name        1955 non-null   object
#  2   transaction_date  1980 non-null   object
#  3   aisle             1980 non-null   object
#  4   product_name      1980 non-null   object
#  5   quantity          1980 non-null   float64
#  6   unit_price        1980 non-null   float64
#  7   total_amount      1980 non-null   float64
#  8   discount_amount   1980 non-null   float64
#  9   final_amount      1980 non-null   float64
#  10  loyalty_points    1980 non-null   int64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 170.3+ KB

# %%
df.describe()
# Out:
#        customer_id     quantity   unit_price  total_amount  discount_amount  \
# count  1980.000000  1980.000000  1980.000000   1980.000000      1980.000000
# mean   5542.958081     2.968182    15.488045     45.902576         4.469591
# std    2575.771856     1.419028     8.400823     35.018599         4.962001
# min    1006.000000     1.000000     0.990000      1.010000         0.000000
# 25%    3271.500000     2.000000     8.240000     18.000000         1.240000
# 50%    5582.500000     3.000000    15.190000     37.130000         3.045000
# 75%    7791.750000     4.000000    22.862500     67.930000         5.402500
# max    9998.000000     5.000000    29.980000    149.900000        29.940000
#
#        final_amount  loyalty_points
# count   1980.000000     1980.000000
# mean      41.432985      255.147980
# std       32.593328      146.009333
# min       -3.430000        0.000000
# 25%       15.800000      128.000000
# 50%       32.820000      265.500000
# 75%       60.800000      378.000000
# max      147.910000      500.000000

# %%
df=pd.read_csv("/content/data.csv")

# %%
df.head(2)
# Out:
#                artist and title  wks   t10  pk     x?  PkStreams       total  \
# 0  The Weeknd - Blinding Lights  347  64.0   1  (x13)   52375259  5441240333
# 1     Ed Sheeran - Shape of You  424  34.0   1  (x14)   64217796  4470842634
#
#   artist name        song name  \
# 0  The Weeknd  Blinding Lights
# 1  Ed Sheeran     Shape of You
#
#                                               lyrics
# 0  Yeah I've been tryna call I've been on my own ...
# 1  The club isn't the best place to find a lover ...

# %%
df.tail(2)
# Out:
#             artist and title  wks  t10   pk   x?  PkStreams   total  \
# 8056          iSHi - Push It    1  NaN  236  NaN     173886  173886
# 8057  Handsome Ghost - Steps    1  NaN  239  NaN     166910  166910
#
#          artist name song name  \
# 8056            iSHi   Push It
# 8057  Handsome Ghost     Steps
#
#                                                  lyrics
# 8056  Push it to the limit, if you wanna win it Harb...
# 8057  Over on your island, counting your clocks Mome...

# %%
df.shape
# Out:
# (8058, 10)

# %%
df.columns
# Out:
# Index(['artist and title', 'wks', 't10', 'pk', 'x?', 'PkStreams', 'total',
#        'artist name', 'song name', 'lyrics'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8058 entries, 0 to 8057
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist and title  8058 non-null   object
#  1   wks               8058 non-null   int64
#  2   t10               810 non-null    float64
#  3   pk                8058 non-null   int64
#  4   x?                334 non-null    object
#  5   PkStreams         8058 non-null   int64
#  6   total             8058 non-null   int64
#  7   artist name       8056 non-null   object
#  8   song name         8058 non-null   object
#  9   lyrics            8043 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 629.7+ KB

# %%
df.describe()
# Out:
#                wks         t10           pk     PkStreams         total
# count  8058.000000  810.000000  8058.000000  8.058000e+03  8.058000e+03
# mean     15.510549    8.209877    83.664185  1.156726e+07  1.419280e+08
# std      30.921408    8.984420    60.125907  1.025781e+07  3.394366e+08
# min       1.000000    1.000000     1.000000  1.669100e+05  1.669100e+05
# 25%       1.000000    1.000000    30.000000  5.368128e+06  8.916825e+06
# 50%       4.000000    5.000000    74.000000  8.941470e+06  2.798093e+07
# 75%      17.000000   13.000000   132.000000  1.414555e+07  1.188043e+08
# max     457.000000   71.000000   246.000000  1.288961e+08  5.441240e+09

# %%
print(df["wks"])
# Out:
# 0       347
# 1       424
# 2       218
# 3       333
# 4       343
#        ...
# 8053      1
# 8054      1
# 8055      1
# 8056      1
# 8057      1
# Name: wks, Length: 8058, dtype: int64

# %%
print(df[["wks","pk"]])
# Out:
#       wks   pk
# 0     347    1
# 1     424    1
# 2     218    1
# 3     333   16
# 4     343    4
# ...   ...  ...
# 8053    1  220
# 8054    1  234
# 8055    1  223
# 8056    1  236
# 8057    1  239
#
# [8058 rows x 2 columns]

# %%
print(df.loc[0])
print(df.loc[0:2])
# Out:
# artist and title                         The Weeknd - Blinding Lights
# wks                                                               347
# t10                                                              64.0
# pk                                                                  1
# x?                                                              (x13)
# PkStreams                                                    52375259
# total                                                      5441240333
# artist name                                                The Weeknd
# song name                                             Blinding Lights
# lyrics              Yeah I've been tryna call I've been on my own ...
# Name: 0, dtype: object
#                artist and title  wks   t10  pk     x?  PkStreams       total  \
# 0  The Weeknd - Blinding Lights  347  64.0   1  (x13)   52375259  5441240333
# 1     Ed Sheeran - Shape of You  424  34.0   1  (x14)   64217796  4470842634
# 2      Harry Styles - As It Was  218  60.0   1  (x11)   78460903  4417264164
#
#     artist name        song name  \
# 0    The Weeknd  Blinding Lights
# 1    Ed Sheeran     Shape of You
# 2  Harry Styles        As It Was
#
#                                               lyrics
# 0  Yeah I've been tryna call I've been on my own ...
# 1  The club isn't the best place to find a lover ...
# 2  ﻿ As It Was - Harry Styles Come on Harry we wa...

# %%
print(df.iloc[0])
# Out:
# artist and title                         The Weeknd - Blinding Lights
# wks                                                               347
# t10                                                              64.0
# pk                                                                  1
# x?                                                              (x13)
# PkStreams                                                    52375259
# total                                                      5441240333
# artist name                                                The Weeknd
# song name                                             Blinding Lights
# lyrics              Yeah I've been tryna call I've been on my own ...
# Name: 0, dtype: object

# %%
print(df.iloc[0:3,0:2])
# Out:
#                artist and title  wks
# 0  The Weeknd - Blinding Lights  347
# 1     Ed Sheeran - Shape of You  424
# 2      Harry Styles - As It Was  218

# %%
print(df[df["wks"]<100])
# Out:
#                                     artist and title  wks   t10   pk     x?  \
# 34                                       ROSÉ - APT.   92  36.0    1   (x3)
# 47    Mariah Carey - All I Want for Christmas Is You   92  42.0    1  (x13)
# 56                                  Bad Bunny - DtMF   81  25.0    1   (x7)
# 57                            Alex Warren - Ordinary   76  37.0    1   (x7)
# 60                           sombr - back to friends   70  49.0    1   (x1)
# ...                                              ...  ...   ...  ...    ...
# 8053                         Mariah Carey - Infinity    1   NaN  220    NaN
# 8054                Twenty One Pilots - Fairly Local    1   NaN  234    NaN
# 8055                           Ludacris - Good Lovin    1   NaN  223    NaN
# 8056                                  iSHi - Push It    1   NaN  236    NaN
# 8057                          Handsome Ghost - Steps    1   NaN  239    NaN
#
#       PkStreams       total        artist name  \
# 34     87041494  2484667419               ROSÉ
# 47     92506541  2117164649       Mariah Carey
# 56     88786254  2025045584          Bad Bunny
# 57     40299624  2021840077        Alex Warren
# 60     42212664  1998294246              sombr
# ...         ...         ...                ...
# 8053     177495      177495       Mariah Carey
# 8054     176713      176713  Twenty One Pilots
# 8055     174256      174256           Ludacris
# 8056     173886      173886               iSHi
# 8057     166910      166910     Handsome Ghost
#
#                             song name  \
# 34                               APT.
# 47    All I Want for Christmas Is You
# 56                               DtMF
# 57                           Ordinary
# 60                    back to friends
# ...                               ...
# 8053                         Infinity
# 8054                     Fairly Local
# 8055                       Good Lovin
# 8056                          Push It
# 8057                            Steps
#
#                                                  lyrics
# 34    (채영이가 좋아하는 랜덤게임) (랜덤게임, game start!) 아파트, 아파트 ...
# 47    I don't want a lot for Christmas There is just...
# 56    Eh, eh, eh eh Otro sunset bonito que veo en Sa...
# 57    They say, "The holy water's watered down And t...
# 60    Touch my body tender 'Cause the feeling makes ...
# ...                                                 ...
# 8053  Why you mad? Talking about you mad Could it be...
# 8054  I'm fairly local, I've been around I've seen t...
# 8055  I keep dwellin' on the past, babe Know what I ...
# 8056  Push it to the limit, if you wanna win it Harb...
# 8057  Over on your island, counting your clocks Mome...
#
# [7889 rows x 10 columns]

# %%
df["yeni sütun"] = df["wks"]*12

# %%
df
# Out:
#                          artist and title  wks   t10   pk     x?  PkStreams  \
# 0            The Weeknd - Blinding Lights  347  64.0    1  (x13)   52375259
# 1               Ed Sheeran - Shape of You  424  34.0    1  (x14)   64217796
# 2                Harry Styles - As It Was  218  60.0    1  (x11)   78460903
# 3     The Neighbourhood - Sweater Weather  333   NaN   16    NaN   21624450
# 4       Lewis Capaldi - Someone You Loved  343  15.0    4    NaN   24962682
# ...                                   ...  ...   ...  ...    ...        ...
# 8053              Mariah Carey - Infinity    1   NaN  220    NaN     177495
# 8054     Twenty One Pilots - Fairly Local    1   NaN  234    NaN     176713
# 8055                Ludacris - Good Lovin    1   NaN  223    NaN     174256
# 8056                       iSHi - Push It    1   NaN  236    NaN     173886
# 8057               Handsome Ghost - Steps    1   NaN  239    NaN     166910
#
#            total        artist name          song name  \
# 0     5441240333         The Weeknd    Blinding Lights
# 1     4470842634         Ed Sheeran       Shape of You
# 2     4417264164       Harry Styles          As It Was
# 3     4142643719  The Neighbourhood    Sweater Weather
# 4     3933581891      Lewis Capaldi  Someone You Loved
# ...          ...                ...                ...
# 8053      177495       Mariah Carey           Infinity
# 8054      176713  Twenty One Pilots       Fairly Local
# 8055      174256           Ludacris         Good Lovin
# 8056      173886               iSHi            Push It
# 8057      166910     Handsome Ghost              Steps
#
#                                                  lyrics  yeni sütun
# 0     Yeah I've been tryna call I've been on my own ...        4164
# 1     The club isn't the best place to find a lover ...        5088
# 2     ﻿ As It Was - Harry Styles Come on Harry we wa...        2616
# 3     And all I am is a man I want the world in my h...        3996
# 4     I'm going under and this time I fear there's n...        4116
# ...                                                 ...         ...
# 8053  Why you mad? Talking about you mad Could it be...          12
# 8054  I'm fairly local, I've been around I've seen t...          12
# 8055  I keep dwellin' on the past, babe Know what I ...          12
# 8056  Push it to the limit, if you wanna win it Harb...          12
# 8057  Over on your island, counting your clocks Mome...          12
#
# [8058 rows x 11 columns]

# %%
print(df.sort_values("wks"))
# Out:
#                                     artist and title  wks   t10   pk     x?  \
# 8048                   Jidenna - Classic Man - Remix    1   NaN  224    NaN
# 8047                   The Fray - How to Save a Life    1   NaN  220    NaN
# 8046  Elina Born & Stig Rästa - Goodbye To Yesterday    1   NaN  237    NaN
# 8045                   Guy Sebastian - Tonight Again    1   NaN  232    NaN
# 8044                  Of Monsters and Men - Crystals    1   NaN  246    NaN
# ...                                              ...  ...   ...  ...    ...
# 20                               Vance Joy - Riptide  415   NaN   16    NaN
# 22                      OneRepublic - Counting Stars  424  24.0    3   (x5)
# 1                          Ed Sheeran - Shape of You  424  34.0    1  (x14)
# 14                        Imagine Dragons - Believer  425   NaN   16    NaN
# 9                               Ed Sheeran - Perfect  457  15.0    4    NaN
#
#       PkStreams       total              artist name             song name  \
# 8048     186979      186979                  Jidenna           Classic Man
# 8047     187186      187186                 The Fray    How to Save a Life
# 8046     187762      187762  Elina Born & Stig Rästa  Goodbye To Yesterday
# 8045     192663      192663            Guy Sebastian         Tonight Again
# 8044     194198      194198      Of Monsters and Men              Crystals
# ...         ...         ...                      ...                   ...
# 20     16836644  2983453847                Vance Joy               Riptide
# 22     11170130  2739753518              OneRepublic        Counting Stars
# 1      64217796  4470842634               Ed Sheeran          Shape of You
# 14     16864827  3353483545          Imagine Dragons              Believer
# 9      24763619  3730229095               Ed Sheeran               Perfect
#
#                                                  lyrics  yeni sütun
# 8048  I'm the only nigga doin' it, you other niggas ...          12
# 8047  Step one, you say, "We need to talk" He walks,...          12
# 8046  I woke up at 6 a.m. My eyes were closed but my...          12
# 8045  Oh, everyone's got their problems There's alwa...          12
# 8044  Lost in skies of powdered gold Caught in cloud...          12
# ...                                                 ...         ...
# 20    I was scared of dentists and the dark I was sc...        4980
# 22    Counting Stars - OneRepublic Lately, I've been...        5088
# 1     The club isn't the best place to find a lover ...        5088
# 14    First things first, I'ma say all the words ins...        5100
# 9     I found a love, for me Darling, just dive righ...        5484
#
# [8058 rows x 11 columns]

# %%
print(df.sort_values("t10", ascending= False))
# Out:
#                         artist and title  wks   t10   pk     x?  PkStreams  \
# 6     Billie Eilish - BIRDS OF A FEATHER  114  71.0    1   (x3)   66726270
# 0           The Weeknd - Blinding Lights  347  64.0    1  (x13)   52375259
# 7           Lady Gaga - Die With A Smile  101  61.0    1  (x30)   78624101
# 2               Harry Styles - As It Was  218  60.0    1  (x11)   78460903
# 60               sombr - back to friends   70  49.0    1   (x1)   42212664
# ...                                  ...  ...   ...  ...    ...        ...
# 8053             Mariah Carey - Infinity    1   NaN  220    NaN     177495
# 8054    Twenty One Pilots - Fairly Local    1   NaN  234    NaN     176713
# 8055               Ludacris - Good Lovin    1   NaN  223    NaN     174256
# 8056                      iSHi - Push It    1   NaN  236    NaN     173886
# 8057              Handsome Ghost - Steps    1   NaN  239    NaN     166910
#
#            total        artist name           song name  \
# 6     3821072735      Billie Eilish  BIRDS OF A FEATHER
# 0     5441240333         The Weeknd     Blinding Lights
# 7     3797546382          Lady Gaga    Die With A Smile
# 2     4417264164       Harry Styles           As It Was
# 60    1998294246              sombr     back to friends
# ...          ...                ...                 ...
# 8053      177495       Mariah Carey            Infinity
# 8054      176713  Twenty One Pilots        Fairly Local
# 8055      174256           Ludacris          Good Lovin
# 8056      173886               iSHi             Push It
# 8057      166910     Handsome Ghost               Steps
#
#                                                  lyrics  yeni sütun
# 6     I want you to stay 'Til I'm in the grave 'Til ...        1368
# 0     Yeah I've been tryna call I've been on my own ...        4164
# 7     Ooh, ooh I, I just woke up from a dream But yo...        1212
# 2     ﻿ As It Was - Harry Styles Come on Harry we wa...        2616
# 60    Touch my body tender 'Cause the feeling makes ...         840
# ...                                                 ...         ...
# 8053  Why you mad? Talking about you mad Could it be...          12
# 8054  I'm fairly local, I've been around I've seen t...          12
# 8055  I keep dwellin' on the past, babe Know what I ...          12
# 8056  Push it to the limit, if you wanna win it Harb...          12
# 8057  Over on your island, counting your clocks Mome...          12
#
# [8058 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8058 entries, 0 to 8057
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist and title  8058 non-null   object
#  1   wks               8058 non-null   int64
#  2   t10               810 non-null    float64
#  3   pk                8058 non-null   int64
#  4   x?                334 non-null    object
#  5   PkStreams         8058 non-null   int64
#  6   total             8058 non-null   int64
#  7   artist name       8056 non-null   object
#  8   song name         8058 non-null   object
#  9   lyrics            8043 non-null   object
#  10  yeni sütun        8058 non-null   int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 692.6+ KB

# %%
print(df.isnull().sum())
# Out:
# artist and title       0
# wks                    0
# t10                 7248
# pk                     0
# x?                  7724
# PkStreams              0
# total                  0
# artist name            2
# song name              0
# lyrics                15
# yeni sütun             0
# dtype: int64

# %%
df2= df.fillna(0)

# %%
df2.isnull().sum()
# Out:
# artist and title    0
# wks                 0
# t10                 0
# pk                  0
# x?                  0
# PkStreams           0
# total               0
# artist name         0
# song name           0
# lyrics              0
# yeni sütun          0
# dtype: int64

# %%
df3 = df.dropna()

# %%
df3.shape
# Out:
# (334, 11)

# %%
df.shape
# Out:
# (8058, 11)

# %%
ogrenciler  = pd.DataFrame({
    "ogrenci_id":[1,2,3],
    "isim" : ["Ayşe","Fatma","Hayriye"],
    "ogrenci_no" :[221,796,207]
})

notlar = pd.DataFrame({
    "ogrenci_id" :[1,2,3],
    "ders" : ["Matematik","Fizik","Kimya"],
    "not" : [85,90,78],
    "dönem" : [1,1,2]
})

# %%
#sadece ortak alanlara göre
df_merge = pd.merge(ogrenciler,notlar, on="ogrenci_id" , how= "inner")

# %%
df_merge
# Out:
#    ogrenci_id     isim  ogrenci_no       ders  not  dönem
# 0           1     Ayşe         221  Matematik   85      1
# 1           2    Fatma         796      Fizik   90      1
# 2           3  Hayriye         207      Kimya   78      2

# %%
df_left = pd.merge(ogrenciler,notlar, on="ogrenci_id" , how= "left")

# %%
df_left
# Out:
#    ogrenci_id     isim  ogrenci_no       ders  not
# 0           1     Ayşe         221  Matematik   85
# 1           2    Fatma         796      Fizik   90
# 2           3  Hayriye         207      Kimya   78

# %%
df_outer = pd.merge(ogrenciler,notlar, on="ogrenci_id" , how= "outer")

# %%
df_outer
# Out:
#    ogrenci_id     isim  ogrenci_no       ders  not  dönem
# 0           1     Ayşe         221  Matematik   85      1
# 1           2    Fatma         796      Fizik   90      1
# 2           3  Hayriye         207      Kimya   78      2

# %%
df= pd.DataFrame({
    "departman" : ["satış", "IT","satış", "IT","IK"],
    "isim" : ["Ayşe","Fatma","Hayriye","Tripcan","Zıpırcan"],
    "maas" : [15000,20000,232320,3543535,123124510]
})

# %%
#departmana göre ortalama maaaş
print(df.groupby("departman")["maas"].mean())
# Out:
# departman
# IK       123124510.0
# IT         1781767.5
# satış       123660.0
# Name: maas, dtype: float64

# %%
print(df.groupby("departman")["maas"].sum())
# Out:
# departman
# IK       123124510
# IT         3563535
# satış       247320
# Name: maas, dtype: int64

# %%
print(df.groupby("departman")["isim"].count())
# Out:
# departman
# IK       1
# IT       2
# satış    2
# Name: isim, dtype: int64

# %%
df1 = pd.DataFrame({"isim": ["Zıpırcan","Tripcan"], "yas": [23,28]})
df2 = pd.DataFrame({"isim":["İlgisu", "Nurella"], "yas":[30,22]})

# %%
df1
# Out:
#        isim  yas
# 0  Zıpırcan   23
# 1   Tripcan   28

# %%
df2
# Out:
#       isim  yas
# 0   İlgisu   30
# 1  Nurella   22

# %%
kaprisnaz=pd.concat([df1,df2],ignore_index=True)

kaprisnaz
# Out:
#        isim  yas
# 0  Zıpırcan   23
# 1   Tripcan   28
# 2    İlgisu   30
# 3   Nurella   22

# %%
df3=pd.DataFrame({"sehir":["Bebek","Üsküdar"]})
kokuşsu=pd.concat([df1,df3],axis=1)
kokuşsu
# Out:
#        isim  yas    sehir
# 0  Zıpırcan   23    Bebek
# 1   Tripcan   28  Üsküdar

# %%
df= pd.DataFrame({
    "sehir":["İstanbul","Ankara","Erzincan","Manisa","Denizli"],
    "urun" :["maskara","eyeliner","gloss","eyeliner","gloss"],
    "satis":[1000,1500,2000,23000,21232]
})

pivot= pd.pivot_table(df,index="sehir",columns="urun",values="satis")
pivot
# Out:
# urun      eyeliner    gloss  maskara
# sehir
# Ankara      1500.0      NaN      NaN
# Denizli        NaN  21232.0      NaN
# Erzincan       NaN   2000.0      NaN
# Manisa     23000.0      NaN      NaN
# İstanbul       NaN      NaN   1000.0

# %%
df
# Out:
#       sehir      urun  satis
# 0  İstanbul   maskara   1000
# 1    Ankara  eyeliner   1500
# 2  Erzincan     gloss   2000
# 3    Manisa  eyeliner  23000
# 4   Denizli     gloss  21232

# %%
df2 = pd.DataFrame({"isim":["ilgisu", "nurella"], "yas":[30,65]})

df2['isim_buyutulmus'] = df2["isim"].apply(str.upper)
df2
# Out:
#       isim  yas isim_buyutulmus
# 0   ilgisu   30          ILGISU
# 1  nurella   65         NURELLA

# %%
df = pd.DataFrame ({
    "id" : ["1","2","3"],
    "fiyat": ["19.99","25.50","30.21"]
})

df["id"] = df["id"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   fiyat   3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df["fiyat"] = df["fiyat"].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   fiyat   3 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 176.0 bytes

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.DataFrame({
      "ay": ["Ocak", "Şubat","Mart","Nisan"],
      "satis":[1200,1800,900,1500]})

# %%
#çizgi grafik
df.plot(x="ay",y="satis",kind="line", marker="o")
plt.title("Ay Bazlı Satış")
plt.xlabel("Ay")
plt.ylabel("Satış Miktarı")
plt.show()

# %%
#bar grafik
df.plot(x="ay",y="satis",kind="bar", color ="skyblue")
plt.title("Ay Bazlı Satış")
plt.xlabel("Ay")
plt.ylabel("Satış Miktarı")
plt.show()

# %%
df.set_index("ay").plot(kind="pie",y="satis",autopct="%1.1f%%")
plt.title("Ay Bazlı Satış")
plt.show()
